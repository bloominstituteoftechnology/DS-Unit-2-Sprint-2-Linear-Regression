# %% [markdown]
# # Model Diagnostics
#
# The purpose of this assigment is introduce you to a new library for linear regression called statmodels which is much better suited for inferential modeling than sklearn. This assignment is also to familiarize yourself with some of most important procedures for improving the interpretability of regression coefficients. You will also perform important statistical tests that will help establish that whether or not important assumptions that safeguard the interpretability of OLS coefficients have been met.
#
# We will continue to use the Ames Housing Dataset so that you can focus on the techniques and not on cleaning/getting associated with a brand new dataset.

# %% [markdown]
# ## 1.1 Choose an X and Y variable from your dataset and use them to create a Seaborn Regplot

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv')
pd.set_option('display.max_columns', 100)

df = df.drop(['MasVnrType', 'MasVnrArea', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature', 'LotFrontage', 
              'Alley', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical',
              'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond'], axis=1)
df['Street'] = df['Street'].replace('Pave', 1)
df['Street'] = df['Street'].replace('Grvl', 0)
lot_shape = {'Reg': 3, 'IR1': 2, 'IR2': 1, 'IR3': 0}
df['LotShape'].replace(lot_shape, inplace = True)
land_contour = {'Lvl': 3, 'Bnk': 2, 'HLS': 1, 'Low': 0}
df['LandContour'].replace(land_contour, inplace = True)
utilities = {'AllPub': 3, 'NoSewr': 2, 'NoSeWa': 1, 'ELO': 0}
df['Utilities'].replace(utilities, inplace = True)
land_slope = {'Gtl': 2, 'Mod': 1, 'Sev': 0}
df['LandSlope'].replace(land_slope, inplace = True)
lot_config = {'FR3': 4, 'FR2': 3, 'CulDSac': 2, 'Corner': 1, 'Inside': 0}
df['LotConfig'].replace(lot_config, inplace = True)
df['Age'] = 2019 - df['YearBuilt']
df['Age_Since_Remodel'] = 2019 - df['YearRemodAdd']
ext_qual = {'Ex': 4, 'Gd': 3, 'TA': 2, 'Fa': 1, 'Po': 0}
df['ExterQual'].replace(ext_qual, inplace = True)
ext_cond = {'Ex': 4, 'Gd': 3, 'TA': 2, 'Fa': 1, 'Po': 0}
df['ExterCond'].replace(ext_cond, inplace = True)
df['CentralAir'] = df['CentralAir'].replace('Y', 1)
df['CentralAir'] = df['CentralAir'].replace('N', 0)
df['Year_Since_Sold'] = 2019 - df['YrSold']
df['has_garage'] = df['GarageArea'] != 0
df['has_garage'] = df['has_garage'].astype(int)
type_of_heat = {'GasA': 5, 'GasW': 4, 'Floor': 3, 'Grav': 2, 'Wall': 1, 'OthW': 0}
df['Heating'].replace(type_of_heat, inplace = True)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea  Street  LotShape  LandContour  Utilities  \
# 0   1          60       RL     8450       1         3            3          3
# 1   2          20       RL     9600       1         3            3          3
# 2   3          60       RL    11250       1         2            3          3
# 3   4          70       RL     9550       1         2            3          3
# 4   5          60       RL    14260       1         2            3          3
#
#    LotConfig  LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0          0          2      CollgCr       Norm       Norm     1Fam
# 1          3          2      Veenker      Feedr       Norm     1Fam
# 2          0          2      CollgCr       Norm       Norm     1Fam
# 3          1          2      Crawfor       Norm       Norm     1Fam
# 4          3          2      NoRidge       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# ...

# %%
# We can create scatterplots that show the confidence interval!
# these should be required on anylinear regression graphs.
price = df.SalePrice
square_feet = df['1stFlrSF'] +  + df['BsmtFinSF2'] + df['2ndFlrSF'] + df['GrLivArea']
# print(square_feet)
fig = sns.regplot(square_feet, price, color='purple').set_title('Total Square Feet by Price')

# %%
print(df.columns, "\n")
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageCars', 'GarageArea', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice', 'Age', 'Age_Since_Remodel',
# ...

# %%
# Drop columns that I don't care about

df = df.drop(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
       'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
       'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
       'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation',
       'Heating','HeatingQC', 'CentralAir', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 
       'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
       'Functional', 'Fireplaces', 'GarageCars', 'GarageArea', 'PavedDrive',
       'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'Year_Since_Sold', 'has_garage'], axis=1)

df.head()
# Out:
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 0         706           0        150          856       856       854
# 1         978           0        284         1262      1262         0
# 2         486           0        434          920       920       866
# 3         216           0        540          756       961       756
# 4         655           0        490         1145      1145      1053
#
#    GrLivArea  SalePrice  Age  Age_Since_Remodel
# 0       1710     208500   16                 16
# 1       1262     181500   43                 43
# 2       1786     223500   18                 17
# 3       1717     140000  104                 49
# 4       2198     250000   19                 19

# %% [markdown]
# ## 1.2 Now using the X variables that you feel like will be the best predictors of y use statsmodel to run the multiple regression between these variables and Y. You don't need to use every X variable in your dataset, in fact it's probably better if you don't. Just pick ones that you have already cleaned that seem the most relevant to house prices.

# %%
sns.set(style="ticks", color_codes=True)

# Generate a list of column headers not including price
x_columns = df.columns.drop('SalePrice')

# Only plot the scatterplot of x variables with our y variable
fig = sns.pairplot(data=df, y_vars=['SalePrice'], x_vars=x_columns)

# %% [markdown]
# ## 1.3 Identify the standard errors and P-Values of these coefficients in the output table. What is the interpretation of the P-values here?

# %%
X = df[['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 
       'Age', 'Age_Since_Remodel']]

y = df['SalePrice']
print(X.shape)
X.head()
# Out:
# (1460, 9)
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 0         706           0        150          856       856       854
# 1         978           0        284         1262      1262         0
# 2         486           0        434          920       920       866
# 3         216           0        540          756       961       756
# 4         655           0        490         1145      1145      1053
#
#    GrLivArea  Age  Age_Since_Remodel
# 0       1710   16                 16
# 1       1262   43                 43
# 2       1786   18                 17
# 3       1717  104                 49
# 4       2198   19                 19

# %%
# Use Statsmodels to run a regression

# This is like using np.ones to add a vector of ones
# X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
predictions = model.predict(X) 

print_model = model.summary()
regression_results = list(model.params)
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     3425.
# Date:                Fri, 18 Jan 2019   Prob (F-statistic):               0.00
# Time:                        10:58:47   Log-Likelihood:                -17693.
# No. Observations:                1460   AIC:                         3.540e+04
# Df Residuals:                    1452   BIC:                         3.544e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# BsmtFinSF1           22.6812      2.812      8.065      0.000      17.165      28.198
# ...

# %% [markdown]
# ## 1.4 Remove outliers from your dataset and run the regression again. Do you see a change in some coefficients? Which seem to move the most?

# %%
# normalize = abs((X - X.mean()) / X.std())
# print(df.shape)

# df =  (normalize < 3).all(axis=1)

df = df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]

df.shape
# Out:
# (1361, 10)

# %%
# Re-run regression without outliers.

X = df[['BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 
       'Age', 'Age_Since_Remodel']]

y = df['SalePrice']

# This is like using np.ones to add a vector of ones
X = sm.add_constant(X)

model1 = sm.OLS(y, X).fit()
predictions = model1.predict(X) 

print_model1 = model1.summary()
regression_results1 = list(model1.params)

print(print_model1)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.793
# Model:                            OLS   Adj. R-squared:                  0.792
# Method:                 Least Squares   F-statistic:                     648.6
# Date:                Fri, 18 Jan 2019   Prob (F-statistic):               0.00
# Time:                        10:58:47   Log-Likelihood:                -15953.
# No. Observations:                1361   AIC:                         3.192e+04
# Df Residuals:                    1352   BIC:                         3.197e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               5.82e+04   4334.739     13.427      0.000    4.97e+04    6.67e+04
# ...

# %%
for regression_results, regression_results1 in zip(regression_results, regression_results1):
    print([regression_results, regression_results1])
# Out:
# [22.68119004926072, 58203.85769094748]
# [2.841444487195254, 33.67224785574179]
# [7.641813862504015, -12.930670816958752]
# [33.16444839896011, 7.575792984090557]
# [107.31483062185897, 28.31737002287455]
# [87.8119361769956, 68.52758169075432]
# [1.9563814141232356, 65.9364911780817]
# [-396.2250383843583, 8.078772978355211]
# [-318.87116825964904, -510.42757863942074]

# %% [markdown]
# ## 1.5 Create a new log(y) variable and use it to run a log-linear regression of your variables using statmodels

# %%
df['ln_price'] = np.log(df['SalePrice'])

sns.set(style = "ticks", color_codes = True)

# Generate a list of column headers not including price
x_columns = df.columns.drop(['SalePrice','ln_price'])

# Only plot the scatterplot of x variables with our y variable
fig = sns.pairplot(data = df, y_vars = ['ln_price'], x_vars = x_columns)

model2 = sm.OLS(y, X).fit()
predictions = model2.predict(X) 

print_model2 = model2.summary()
regression_results2 = list(model2.params)

print(print_model2)
# Out:
# /Users/danielleromanoff/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.793
# Model:                            OLS   Adj. R-squared:                  0.792
# Method:                 Least Squares   F-statistic:                     648.6
# Date:                Fri, 18 Jan 2019   Prob (F-statistic):               0.00
# Time:                        10:58:47   Log-Likelihood:                -15953.
# No. Observations:                1361   AIC:                         3.192e+04
# ...

# %% [markdown]
# ## 2.1 Run a test for high levels of collinearity in your dataset. Calculate the Variance Inflation Factor for each X variable. Do you see VIF values greater than ten? If so try omitting those X variables and run your regression again. Do the standard errors change? Do the coefficients change? Do the coefficients seem to have an interpretation that matches your intuition?

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

print(X.columns, '\n\n')

vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
# Index(['const', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'Age', 'Age_Since_Remodel'],
#       dtype='object')
#
#
# [28.587948209758043, inf, inf, inf, inf, 65.14560001573115, 98.71542817014675, 113.12554282250271, 1.7991099376717903, 1.6720778672384715]

# %%
X.corr()
# Out:
#                    const  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# const                NaN         NaN         NaN        NaN          NaN
# BsmtFinSF1           NaN    1.000000    0.003206  -0.579316     0.464088
# BsmtFinSF2           NaN    0.003206    1.000000  -0.184549     0.011411
# BsmtUnfSF            NaN   -0.579316   -0.184549   1.000000     0.432930
# TotalBsmtSF          NaN    0.464088    0.011411   0.432930     1.000000
# 1stFlrSF             NaN    0.385898   -0.005019   0.310738     0.773503
# 2ndFlrSF             NaN   -0.207020   -0.070736  -0.009199    -0.255027
# GrLivArea            NaN    0.087157   -0.067470   0.224333     0.332410
# Age                  NaN   -0.235589    0.063407  -0.138183    -0.401882
# Age_Since_Remodel    NaN   -0.115291    0.099875  -0.163181    -0.288512
#
#                    1stFlrSF  2ndFlrSF  GrLivArea       Age  Age_Since_Remodel
# const                   NaN       NaN        NaN       NaN                NaN
# ...

# %%
X = df[[ 'Age', 'Age_Since_Remodel']]

# %%
sns.set(style="ticks", color_codes=True)

# Generate a list of column headers not including price
x_columns = df.columns.drop(['SalePrice', 'ln_price'])

# Only plot the scatterplot of x variables with our y variable
fig = sns.pairplot(data = df, y_vars = ['ln_price'], x_vars = x_columns)

# %% [markdown]
# ## 2.2 Variables that have high levels of multicollinearity should also be highly correlated with each other. Calculate your X matrix's correlation matrix to check if the variables highlighted by the VIF test truly are highly correlated.

# %%
X
# Out:
#       Age  Age_Since_Remodel
# 0      16                 16
# 1      43                 43
# 2      18                 17
# 3     104                 49
# 4      19                 19
# 5      26                 24
# 6      15                 14
# 7      46                 46
# 8      88                 69
# 9      80                 69
# 10     54                 54
# 11     14                 13
# 12     57                 57
# 13     13                 12
# 14     59                 59
# 15     90                 18
# 16     49                 49
# 17     52                 52
# 18     15                 15
# 19     61                 54
# 20     14                 13
# 21     89                 69
# 22     17                 17
# 23     43                 43
# 25     12                 12
# 26     68                 19
# 27     12                 11
# 28     62                 22
# 29     92                 69
# 30     99                 69
# ...   ...                ...
# ...

# %% [markdown]
# ## 2.3 If you have varaibles with high Variance Inflation Factors, try excluding them from your regression. Do your standard errors improve? (get smaller). If high levels of multicollinearity are removed, the precision of the dataset should increase.

# %%
# This is like using np.ones to add a vector of ones
X = sm.add_constant(X)

model3 = sm.OLS(y, X).fit(cov_type='HC3')

predictions = model3.predict(X) 

print_model3 = model3.summary()
print(print_model3)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.403
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     434.8
# Date:                Fri, 18 Jan 2019   Prob (F-statistic):          1.17e-146
# Time:                        10:58:50   Log-Likelihood:                -16675.
# No. Observations:                1361   AIC:                         3.336e+04
# Df Residuals:                    1358   BIC:                         3.337e+04
# Df Model:                           2
# Covariance Type:                  HC3
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              2.489e+05   3312.027     75.149      0.000    2.42e+05    2.55e+05
# ...

# %% [markdown]
# ## 2.4 Recalculate your regression using Robust Standard Errors? What happens to your standard errors?

# %%
##### Your Code Here #####

# %% [markdown]
# ## 2.5 Use scatterplots or Seaborn's pairplot functionality to perform an eyeball test for potential variables that would be candidates for generating polynomial regressors.

# %%
##### Your Code Here #####

# %% [markdown]
# ## 2.6 Use seaborn's residplot to plot the distribution of each x variable's residuals. Does these plots indicate any other features that would be potential candidates for polynomial features.

# %%
##### Your Code Here #####

# %% [markdown]
# ## 2.6 Feature Engineer the appropriate polynomial features from your analysis above and include them in one final log-polynomial, robust standard error, regression. Do the coefficients of this most advanced regression match your intuition better than the coefficients of the very first regression that we ran with the Statmodels library?

# %%
##### Your Code Here #####
