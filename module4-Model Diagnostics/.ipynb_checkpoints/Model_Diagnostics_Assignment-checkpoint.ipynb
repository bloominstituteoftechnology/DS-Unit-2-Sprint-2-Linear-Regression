# %% [markdown]
# # Model Diagnostics
#
# The purpose of this assigment is introduce you to a new library for linear regression called statmodels which is much better suited for inferential modeling than sklearn. This assignment is also to familiarize yourself with some of most important procedures for improving the interpretability of regression coefficients. You will also perform important statistical tests that will help establish that whether or not important assumptions that safeguard the interpretability of OLS coefficients have been met.
#
# We will continue to use the Ames Housing Dataset so that you can focus on the techniques and not on cleaning/getting associated with a brand new dataset.

# %%
##### Your Code Here #####
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
from scipy import stats
model = LinearRegression()
df = pd.read_csv("https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv")
df = df.replace(np.nan,0)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave     0      Reg
# 1   2          20       RL         80.0     9600   Pave     0      Reg
# 2   3          60       RL         68.0    11250   Pave     0      IR1
# 3   4          70       RL         60.0     9550   Pave     0      IR1
# 4   5          60       RL         84.0    14260   Pave     0      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0      0     0           0       0
# 1         Lvl    AllPub    ...            0      0     0           0       0
# 2         Lvl    AllPub    ...            0      0     0           0       0
# 3         Lvl    AllPub    ...            0      0     0           0       0
# 4         Lvl    AllPub    ...            0      0     0           0       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
sqfteq = pd.concat([df["1stFlrSF"],df["1stFlrSF"]**2,df["2ndFlrSF"],df["2ndFlrSF"]**2,df["1stFlrSF"]+df["2ndFlrSF"]],axis=1)
baths = pd.DataFrame(df["BsmtFullBath"]+df["BsmtHalfBath"]+df["FullBath"]+df["HalfBath"])
baths.columns =["TotalBaths"]
sqfteq.columns = ["1F","2F","1FSquared","2FSquared","1F+2F"]

# %%
baths.head()
# Out:
#    TotalBaths
# 0           4
# 1           3
# 2           4
# 3           2
# 4           4

# %%
df.columns.values
# Out:
# array(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars',
# ...

# %% [markdown]
# ## 1.1 Choose an X and Y variable from your dataset and use them to create a Seaborn Regplot

# %%
x = df["LotArea"]
y = df["SalePrice"]
fig = sns.regplot(x, y, color='blue').set_title('Height by Weight')

# %% [markdown]
# ## 1.2 Now using the X variables that you feel like will be the best predictors of y use statsmodel to run the multiple regression between these variables and Y. You don't need to use every X variable in your dataset, in fact it's probably better if you don't. Just pick ones that you have already cleaned that seem the most relevant to house prices.

# %%
##### Your Code Here #####
x = pd.concat( [ df[["OverallQual", "GarageCars", "TotRmsAbvGrd", "BedroomAbvGr", "Fireplaces"]], sqfteq, baths] , axis=1 )
y = df["SalePrice"]
X = sm.add_constant(x)
model = sm.OLS(y,X).fit()
predictions = model.predict(X)

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.800
# Model:                            OLS   Adj. R-squared:                  0.799
# Method:                 Least Squares   F-statistic:                     581.2
# Date:                Thu, 17 Jan 2019   Prob (F-statistic):               0.00
# Time:                        16:11:46   Log-Likelihood:                -17368.
# No. Observations:                1460   AIC:                         3.476e+04
# Df Residuals:                    1449   BIC:                         3.482e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -1.098e+05   7501.896    -14.638      0.000   -1.25e+05   -9.51e+04
# ...

# %% [markdown]
# ## 1.3 Identify the standard errors and P-Values of these coefficients in the output table. What is the interpretation of the P-values here?

# %%
##### Your Code Here #####

# %% [markdown]
# when doing hypothesis testing, we start with the null hypothesis. We are testing an input and seeing if there is a function that produces our observed value. We assume that the input has no effect. Then we test if that hypothesis is true. The p-value is the probability the null hypothesis is true.

# %% [markdown]
# ## 1.4 Remove outliers from your dataset and run the regression again. Do you see a change in some coefficients? Which seem to move the most?

# %%
df1 = pd.concat( [ df[["SalePrice",  "OverallQual", "GarageCars", "TotRmsAbvGrd", "BedroomAbvGr", "Fireplaces"]],\
                  sqfteq, baths] , axis=1 )
df1 = df1[(np.abs(stats.zscore(df1)) < 3).all(axis=1)]
df1.columns.values
# Out:
# array(['SalePrice', 'OverallQual', 'GarageCars', 'TotRmsAbvGrd',
#        'BedroomAbvGr', 'Fireplaces', '1F', '2F', '1FSquared', '2FSquared',
#        '1F+2F', 'TotalBaths'], dtype=object)

# %%
##### Your Code Here #####
x = df1.drop(["SalePrice"],axis =1)
y = df1["SalePrice"]


X = sm.add_constant(x)
model = sm.OLS(y,X).fit()
predictions = model.predict(X)

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.820
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     627.8
# Date:                Thu, 17 Jan 2019   Prob (F-statistic):               0.00
# Time:                        16:13:55   Log-Likelihood:                -16154.
# No. Observations:                1387   AIC:                         3.233e+04
# Df Residuals:                    1376   BIC:                         3.239e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -3.395e+04   9481.790     -3.581      0.000   -5.26e+04   -1.54e+04
# ...

# %% [markdown]
# ## 1.5 Create a new log(y) variable and use it to run a log-linear regression of your variables using statmodels

# %%
##### Your Code Here #####
x = df1.drop(["SalePrice"],axis =1)
y = np.log(df1["SalePrice"])


X = sm.add_constant(x)
model = sm.OLS(y,X).fit()
predictions = model.predict(X)

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.825
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                     649.5
# Date:                Thu, 17 Jan 2019   Prob (F-statistic):               0.00
# Time:                        16:15:39   Log-Likelihood:                 622.24
# No. Observations:                1387   AIC:                            -1222.
# Df Residuals:                    1376   BIC:                            -1165.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           10.3886      0.053    196.139      0.000      10.285      10.492
# ...

# %% [markdown]
# ## 2.1 Run a test for high levels of collinearity in your dataset. Calculate the Variance Inflation Factor for each X variable. Do you see VIF values greater than ten? If so try omitting those X variables and run your regression again. Do the standard errors change? Do the coefficients change? Do the coefficients seem to have an interpretation that matches your intuition?

# %%
##### Your Code Here #####
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = [variance_inflation_factor(X.values, i ) for i in range(X.shape[1])]
print(vif)
# Out:
# [161.71289793214427, 2.0175396505011953, 1.7418398872387835, 3.730435905985725, 2.047317653947346, 1.33614820905447, inf, 39.03617058332142, inf, 15.39697359684572, inf, 1.7972652062308656]
# C:\Users\cwcol\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:181: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %% [markdown]
# ## 2.2 Variables that have high levels of multicollinearity should also be highly correlated with each other. Calculate your X matrix's correlation matrix to check if the variables highlighted by the VIF test truly are highly correlated.

# %%
##### Your Code Here #####
x.corr()
# Out:
#               OverallQual  GarageCars  TotRmsAbvGrd  BedroomAbvGr  Fireplaces  \
# OverallQual      1.000000    0.573811      0.388239      0.092870    0.357104
# GarageCars       0.573811    1.000000      0.343081      0.087316    0.276030
# TotRmsAbvGrd     0.388239    0.343081      1.000000      0.669957    0.296922
# BedroomAbvGr     0.092870    0.087316      0.669957      1.000000    0.111091
# Fireplaces       0.357104    0.276030      0.296922      0.111091    1.000000
# 1F               0.426198    0.440810      0.333691      0.111621    0.367584
# 2F               0.430702    0.432536      0.323298      0.094517    0.357679
# 1FSquared        0.256850    0.139905      0.589715      0.489040    0.166422
# 2FSquared        0.301201    0.204421      0.615404      0.501042    0.197773
# 1F+2F            0.571027    0.473846      0.807908      0.541161    0.441331
# TotalBaths       0.514989    0.460967      0.435258      0.250105    0.317727
#
# ...

# %% [markdown]
# ## 2.3 If you have varaibles with high Variance Inflation Factors, try excluding them from your regression. Do your standard errors improve? (get smaller). If high levels of multicollinearity are removed, the precision of the dataset should increase.

# %%
##### Your Code Here #####
df2 = df1.drop(labels = ["1F","2F","1FSquared","2FSquared","TotRmsAbvGrd"],axis=1)
x = df2.drop(["SalePrice"],axis=1)
y = np.log(df2["SalePrice"])
X = sm.add_constant(x)
model = sm.OLS(y,X).fit()
predictions = model.predict(X)

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.795
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     892.1
# Date:                Thu, 17 Jan 2019   Prob (F-statistic):               0.00
# Time:                        16:53:33   Log-Likelihood:                 511.93
# No. Observations:                1387   AIC:                            -1010.
# Df Residuals:                    1380   BIC:                            -973.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           10.6296      0.027    387.057      0.000      10.576      10.684
# ...

# %%
x.corr()
# Out:
#               OverallQual  GarageCars  BedroomAbvGr  Fireplaces     1F+2F  \
# OverallQual      1.000000    0.573811      0.092870    0.357104  0.571027
# GarageCars       0.573811    1.000000      0.087316    0.276030  0.473846
# BedroomAbvGr     0.092870    0.087316      1.000000    0.111091  0.541161
# Fireplaces       0.357104    0.276030      0.111091    1.000000  0.441331
# 1F+2F            0.571027    0.473846      0.541161    0.441331  1.000000
# TotalBaths       0.514989    0.460967      0.250105    0.317727  0.596834
#
#               TotalBaths
# OverallQual     0.514989
# GarageCars      0.460967
# BedroomAbvGr    0.250105
# Fireplaces      0.317727
# 1F+2F           0.596834
# TotalBaths      1.000000

# %% [markdown]
# ## 2.4 Recalculate your regression using Robust Standard Errors? What happens to your standard errors?

# %%
##### Your Code Here #####
df2 = df1.drop(labels = ["1F","2F","1FSquared","2FSquared","TotRmsAbvGrd"],axis=1)
x = df2.drop(["SalePrice"],axis=1)
y = np.log(df2["SalePrice"])
X = sm.add_constant(x)
model = sm.OLS(y,X).fit(cov_type="HC3")
predictions = model.predict(X)

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.795
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     733.7
# Date:                Thu, 17 Jan 2019   Prob (F-statistic):               0.00
# Time:                        17:51:39   Log-Likelihood:                 511.93
# No. Observations:                1387   AIC:                            -1010.
# Df Residuals:                    1380   BIC:                            -973.2
# Df Model:                           6
# Covariance Type:                  HC3
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           10.6296      0.033    326.788      0.000      10.566      10.693
# ...

# %% [markdown]
# ## 2.5 Use scatterplots or Seaborn's pairplot functionality to perform an eyeball test for potential variables that would be candidates for generating polynomial regressors.

# %%
##### Your Code Here #####
sns.pairplot(df2)

# %% [markdown]
# ## 2.6 Use seaborn's residplot to plot the distribution of each x variable's residuals. Does these plots indicate any other features that would be potential candidates for polynomial features.

# %%
##### Your Code Here #####
sns.residplot(df2['OverallQual'],y,lowess=True,color ='r',scatter_kws={'color':'blue'})

# %% [markdown]
# ## 2.6 Feature Engineer the appropriate polynomial features from your analysis above and include them in one final log-polynomial, robust standard error, regression. Do the coefficients of this most advanced regression match your intuition better than the coefficients of the very first regression that we ran with the Statmodels library?

# %% [markdown]
# I can't find any polynomial features from looking at my data. A lot looks rank ordered. After the log(price), the sqft features seem linear or at least non polynomial.

# %%
##### Your Code Here #####
