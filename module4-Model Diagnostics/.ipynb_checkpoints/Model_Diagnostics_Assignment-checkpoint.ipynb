# %% [markdown]
# # Model Diagnostics
#
# The purpose of this assigment is introduce you to a new library for linear regression called statmodels which is much better suited for inferential modeling than sklearn. This assignment is also to familiarize yourself with some of most important procedures for improving the interpretability of regression coefficients. You will also perform important statistical tests that will help establish that whether or not important assumptions that safeguard the interpretability of OLS coefficients have been met.
#
# We will continue to use the Ames Housing Dataset so that you can focus on the techniques and not on cleaning/getting associated with a brand new dataset.

# %% [markdown]
# ## 1.1 Choose an X and Y variable from your dataset and use them to create a Seaborn Regplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
##### Your Code Here #####
url = 'https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv'

df = pd.read_csv(url)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
x = df['GrLivArea'].values
y = df['SalePrice'].values

fig, ax = plt.subplots(figsize=(8,8))
sns.regplot(x,y,ax=ax);
# Out:
# /Users/chrislouie/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %%
df.fillna(method='ffill',inplace=True)

# %% [markdown]
# ## 1.2 Now using the X variables that you feel like will be the best predictors of y use statsmodel to run the multiple regression between these variables and Y. You don't need to use every X variable in your dataset, in fact it's probably better if you don't. Just pick ones that you have already cleaned that seem the most relevant to house prices.

# %%
##### Your Code Here #####
df_select = df.select_dtypes(include=['float','int'])
df_select = df_select.drop(columns=['Id'])
df_select.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2    ...      WoodDeckSF  \
# 0          2003       196.0         706           0    ...               0
# 1          1976         0.0         978           0    ...             298
# 2          2002       162.0         486           0    ...               0
# 3          1970         0.0         216           0    ...               0
# 4          2000       350.0         655           0    ...             192
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
df_select = df_select.drop(columns=['GarageYrBlt','MasVnrArea','MiscVal','3SsnPorch', 
                                   'ScreenPorch','EnclosedPorch','MSSubClass',])
df_select.head()
# Out:
#    LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0         65.0     8450            7            5       2003          2003
# 1         80.0     9600            6            8       1976          1976
# 2         68.0    11250            7            5       2001          2002
# 3         60.0     9550            7            5       1915          1970
# 4         84.0    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF    ...      TotRmsAbvGrd  \
# 0         706           0        150          856    ...                 8
# 1         978           0        284         1262    ...                 6
# 2         486           0        434          920    ...                 6
# 3         216           0        540          756    ...                 7
# 4         655           0        490         1145    ...                 9
#
# ...

# %% [markdown]
# ## 1.3 Identify the standard errors and P-Values of these coefficients in the output table. What is the interpretation of the P-values here?

# %%
##### Your Code Here #####
X = df_select.drop(columns=['SalePrice'])
y = df_select['SalePrice']
X = sm.add_constant(X)

model = sm.OLS(y,X).fit()
predictions = model.predict(X)
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.802
# Model:                            OLS   Adj. R-squared:                  0.799
# Method:                 Least Squares   F-statistic:                     215.3
# Date:                Thu, 21 Feb 2019   Prob (F-statistic):               0.00
# Time:                        10:22:49   Log-Likelihood:                -17360.
# No. Observations:                1460   AIC:                         3.478e+04
# Df Residuals:                    1432   BIC:                         3.492e+04
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.933e+04   1.45e+06      0.013      0.989   -2.82e+06    2.86e+06
# ...

# %% [markdown]
# ## 1.4 Remove outliers from your dataset and run the regression again. Do you see a change in some coefficients? Which seem to move the most?

# %%
##### Your Code Here #####
df_n = df_select[(np.abs(stats.zscore(df_select)) < 3).all(axis=1)]

X = df_n.drop(columns=['SalePrice'])
y = df_n['SalePrice']
X = sm.add_constant(X)

model = sm.OLS(y,X).fit()
preds = model.predict(X)
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     344.7
# Date:                Thu, 21 Feb 2019   Prob (F-statistic):               0.00
# Time:                        10:38:06   Log-Likelihood:                -12909.
# No. Observations:                1130   AIC:                         2.587e+04
# Df Residuals:                    1105   BIC:                         2.599e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# LotFrontage     95.8712     39.622      2.420      0.016      18.128     173.614
# ...

# %% [markdown]
# ## 1.5 Create a new log(y) variable and use it to run a log-linear regression of your variables using statmodels

# %%
##### Your Code Here #####
df_select['ln_price'] = np.log(df_select['SalePrice'])

X = df_select.drop(columns=['SalePrice','ln_price'])
y = df_select['ln_price']
X = sm.add_constant(X)

model = sm.OLS(y,X).fit()
preds = model.predict(X)
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               ln_price   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     332.6
# Date:                Thu, 21 Feb 2019   Prob (F-statistic):               0.00
# Time:                        10:39:58   Log-Likelihood:                 716.82
# No. Observations:                1460   AIC:                            -1378.
# Df Residuals:                    1432   BIC:                            -1230.
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           15.2496      6.069      2.513      0.012       3.345      27.154
# ...

# %% [markdown]
# ## 2.1 Run a test for high levels of collinearity in your dataset. Calculate the Variance Inflation Factor for each X variable. Do you see VIF values greater than ten? If so try omitting those X variables and run your regression again. Do the standard errors change? Do the coefficients change? Do the coefficients seem to have an interpretation that matches your intuition?

# %%
##### Your Code Here #####
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif)
# Out:
# [2401289.903221323, 1.2958154718936765, 1.2272490846404802, 2.847000696817112, 1.5095710146616046, 3.1486949620154925, 2.1998662745563897, inf, inf, inf, inf, 1.0813050241988857, 2.1614118883910565, 1.1437504087134889, 2.3698845592006124, 1.4878849189868046, 2.23358886560968, 3.285649495831131, 1.4229192156767199, 5.450019300947091, 5.065712834609862, 1.169251677965617, 1.192871067919357, 1.0635229821905083, 1.041630723455923, 1.0462790372363326]

# %%
df_vif = df_select.drop(columns=['1stFlrSF','2ndFlrSF','GrLivArea','KitchenAbvGr'])

X = df_vif.drop(columns = ['SalePrice','ln_price'])
y = df_vif['ln_price']

X = sm.add_constant(X)
model = sm.OLS(y,X).fit()
preds = model.predict(X)

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               ln_price   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     346.1
# Date:                Thu, 21 Feb 2019   Prob (F-statistic):               0.00
# Time:                        11:08:15   Log-Likelihood:                 666.83
# No. Observations:                1460   AIC:                            -1284.
# Df Residuals:                    1435   BIC:                            -1152.
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           16.9585      6.269      2.705      0.007       4.661      29.256
# ...

# %% [markdown]
# Coefficients don't seem to have changed much.
# Positive = add to house price
# Negative = deter house price
# Presence of other features can make the house price higher value

# %% [markdown]
# ## 2.2 Variables that have high levels of multicollinearity should also be highly correlated with each other. Calculate your X matrix's correlation matrix to check if the variables highlighted by the VIF test truly are highly correlated.

# %%
##### Your Code Here #####
df_select.corr()
# Out:
#               LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# LotFrontage      1.000000  0.272696     0.215195    -0.058140   0.107828
# LotArea          0.272696  1.000000     0.105806    -0.005636   0.014228
# OverallQual      0.215195  0.105806     1.000000    -0.091932   0.572323
# OverallCond     -0.058140 -0.005636    -0.091932     1.000000  -0.375983
# YearBuilt        0.107828  0.014228     0.572323    -0.375983   1.000000
# YearRemodAdd     0.069945  0.013788     0.550684     0.073741   0.592855
# BsmtFinSF1       0.188568  0.214103     0.239666    -0.046231   0.249503
# BsmtFinSF2       0.044697  0.111170    -0.059119     0.040229  -0.049107
# BsmtUnfSF        0.114749 -0.002618     0.308159    -0.136841   0.149040
# TotalBsmtSF      0.328055  0.260833     0.537808    -0.171098   0.391452
# 1stFlrSF         0.373312  0.299475     0.476224    -0.144203   0.281986
# 2ndFlrSF         0.070897  0.050986     0.295493     0.028942   0.010308
# ...

# %%
df_select.cov()
# Out:
#                 LotFrontage       LotArea   OverallQual  OverallCond  \
# LotFrontage      568.679209  6.490788e+04      7.097193    -1.542856
# LotArea        64907.881634  9.962565e+07   1460.548271   -62.602871
# OverallQual        7.097193  1.460548e+03      1.912679    -0.141484
# OverallCond       -1.542856 -6.260287e+01     -0.141484     1.238322
# YearBuilt         77.662800  4.289113e+03     23.906215   -12.636709
# YearRemodAdd      34.436285  2.841344e+03     15.723417     1.694152
# BsmtFinSF1      2050.973353  9.746908e+05    151.176998   -23.464270
# BsmtFinSF2       171.947193  1.790022e+05    -13.189617     7.221779
# BsmtUnfSF       1209.129004 -1.154799e+04    188.316066   -67.285775
# TotalBsmtSF     3432.049550  1.142145e+06    326.303447   -83.528266
# 1stFlrSF        3441.549084  1.155563e+06    254.612835   -62.035256
# 2ndFlrSF         738.027521  2.221512e+05    178.394169    14.059170
# LowQualFinSF      36.769560  2.319329e+03     -2.046234     1.379440
# ...

# %% [markdown]
# ## 2.3 If you have varaibles with high Variance Inflation Factors, try excluding them from your regression. Do your standard errors improve? (get smaller). If high levels of multicollinearity are removed, the precision of the dataset should increase.

# %%
##### Your Code Here #####
df_high = df_select[['1stFlrSF','2ndFlrSF','GrLivArea']]
df_high.corr()
# Out:
#            1stFlrSF  2ndFlrSF  GrLivArea
# 1stFlrSF   1.000000 -0.202646   0.566024
# 2ndFlrSF  -0.202646  1.000000   0.687501
# GrLivArea  0.566024  0.687501   1.000000

# %%
df_high.cov()
# Out:
#                 1stFlrSF       2ndFlrSF      GrLivArea
# 1stFlrSF   149450.079204  -34197.868476  114984.527564
# 2ndFlrSF   -34197.868476  190557.075337  157703.895888
# GrLivArea  114984.527564  157703.895888  276129.633363

# %% [markdown]
# ## 2.4 Recalculate your regression using Robust Standard Errors? What happens to your standard errors?

# %%
##### Your Code Here #####

# %%
X = df_vif.drop(columns=['SalePrice','ln_price'])
y = df_vif['ln_price']

X = sm.add_constant(X)
model = sm.OLS(y,X).fit(cov_type='HC3')
preds = model.predict(X)
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               ln_price   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     251.9
# Date:                Thu, 21 Feb 2019   Prob (F-statistic):               0.00
# Time:                        11:48:13   Log-Likelihood:                 666.83
# No. Observations:                1460   AIC:                            -1284.
# Df Residuals:                    1435   BIC:                            -1152.
# Df Model:                          24
# Covariance Type:                  HC3
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           16.9585      6.161      2.753      0.006       4.884      29.033
# ...

# %% [markdown]
# not much change here

# %% [markdown]
# ## 2.5 Use scatterplots or Seaborn's pairplot functionality to perform an eyeball test for potential variables that would be candidates for generating polynomial regressors.

# %%
##### Your Code Here #####
sns.set(style='ticks',color_codes=True)

x_cols = df_vif.drop(columns=['SalePrice','ln_price']).columns
sns.pairplot(data=df_vif, y_vars=['ln_price'], x_vars=x_cols)
plt.show();

# %% [markdown]
# Uhh I guess we'll pick the ones that are homoskedastic

# %% [markdown]
# ## 2.6 Use seaborn's residplot to plot the distribution of each x variable's residuals. Does these plots indicate any other features that would be potential candidates for polynomial features.

# %%
X = df_vif.drop(columns=['SalePrice','ln_price'])
y = df_vif['ln_price']

# %%
##### Your Code Here #####
sns.set(style='darkgrid')

fig, ax = plt.subplots(ncols=3,nrows=5, figsize=(14,12))
pos = []

for i in range(5):
    for j in range(3):
        pos.append((i,j))

for col,p in zip(X.columns,pos):
    
    sns.residplot(X[col],y,data=df_vif,color='r', ax=ax[p[0]][p[1]],
                  scatter_kws=dict(color='green'),
                  line_kws=dict(color='red'),
                  robust=True)
plt.tight_layout()

# %% [markdown]
# ## 2.6 Feature Engineer the appropriate polynomial features from your analysis above and include them in one final log-polynomial, robust standard error, regression. Do the coefficients of this most advanced regression match your intuition better than the coefficients of the very first regression that we ran with the Statmodels library?

# %%
##### Your Code Here #####
