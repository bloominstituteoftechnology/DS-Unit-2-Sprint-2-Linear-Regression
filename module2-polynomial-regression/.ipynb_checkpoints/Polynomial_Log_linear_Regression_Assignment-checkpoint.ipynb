# %% [markdown]
# # Intermediate Linear Regression Practice
#
# ## Use a Linear Regression model to get the lowest RMSE possible on the following dataset:
#
# [Dataset Folder](https://github.com/ryanleeallred/datasets/tree/master/Ames%20Housing%20Data)
#
# [Raw CSV](https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv)
#
# ## You model must include (at least):
# - A log-transformed y variable
# - Two polynomial features
# - One interaction feature
# - 10 other engineered features
#
# What is the lowest Root-Mean-Squared Error that you are able to obtain? Share your best RMSEs in Slack!
#
# Notes:
#
# There may be some data cleaning that you need to do on some features of this dataset. Linear Regression will only accept numeric values and will not accept
#
# Note* There may not be a clear candidate for an interaction term in this dataset. Include one anyway, sometimes it's a good practice for predictive modeling feature engineering in general.

# %%
##### Your Code Here #####
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import PolynomialFeatures
from math import sqrt

pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',500)

# %%
url = 'https://raw.githubusercontent.com/ryanleeallred/datasets/master/Ames%20Housing%20Data/train.csv'

data = pd.read_csv(url)

print(data.shape)
data.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
data.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# dtype: int64

# %%
df = data.drop(columns = ['LotFrontage', 'Alley', 
                          'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
                          'BsmtFinType2', 'FireplaceQu', 'GarageType',
                          'GarageFinish', 'GarageYrBlt','GarageQual','GarageCond', 'PoolQC',
                          'Fence','MiscFeature'])
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# 0            7            5       2003          2003     Gable  CompShg
# 1            6            8       1976          1976     Gable  CompShg
# 2            7            5       2001          2002     Gable  CompShg
# 3            7            5       1915          1970     Gable  CompShg
# 4            8            5       2000          2000     Gable  CompShg
#
#   Exterior1st Exterior2nd ExterQual ExterCond Foundation  BsmtFinSF1  \
# 0     VinylSd     VinylSd        Gd        TA      PConc         706
# 1     MetalSd     MetalSd        TA        TA     CBlock         978
# 2     VinylSd     VinylSd        Gd        TA      PConc         486
# 3     Wd Sdng     Wd Shng        TA        TA     BrkTil         216
# 4     VinylSd     VinylSd        Gd        TA      PConc         655
#
#    BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir  1stFlrSF  \
# 0           0        150          856    GasA        Ex          Y       856
# 1           0        284         1262    GasA        Ex          Y      1262
# 2           0        434          920    GasA        Ex          Y       920
# 3           0        540          756    GasA        Gd          Y       961
# 4           0        490         1145    GasA        Ex          Y      1145
#
#    2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  \
# 0       854             0       1710             1             0         2
# 1         0             0       1262             0             1         2
# 2       866             0       1786             1             0         2
# 3       756             0       1717             1             0         1
# 4      1053             0       2198             1             0         2
#
#    HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  \
# 0         1             3             1          Gd             8        Typ
# 1         0             3             1          TA             6        Typ
# 2         1             3             1          Gd             6        Typ
# 3         0             3             1          Gd             7        Typ
# 4         1             4             1          Gd             9        Typ
#
#    Fireplaces  GarageCars  GarageArea PavedDrive  WoodDeckSF  OpenPorchSF  \
# 0           0           2         548          Y           0           61
# 1           1           2         460          Y         298            0
# 2           1           2         608          Y           0           42
# 3           1           3         642          Y           0           35
# 4           1           3         836          Y         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# 1              0          0            0         0        0       5    2007
# 2              0          0            0         0        0       9    2008
# 3            272          0            0         0        0       2    2006
# 4              0          0            0         0        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
df.fillna(method='ffill')
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# 5        6          50       RL    14115   Pave      IR1         Lvl
# 6        7          20       RL    10084   Pave      Reg         Lvl
# 7        8          60       RL    10382   Pave      IR1         Lvl
# 8        9          50       RM     6120   Pave      Reg         Lvl
# 9       10         190       RL     7420   Pave      Reg         Lvl
# 10      11          20       RL    11200   Pave      Reg         Lvl
# 11      12          60       RL    11924   Pave      IR1         Lvl
# 12      13          20       RL    12968   Pave      IR2         Lvl
# 13      14          20       RL    10652   Pave      IR1         Lvl
# 14      15          20       RL    10920   Pave      IR1         Lvl
# 15      16          45       RM     6120   Pave      Reg         Lvl
# 16      17          20       RL    11241   Pave      IR1         Lvl
# 17      18          90       RL    10791   Pave      Reg         Lvl
# 18      19          20       RL    13695   Pave      Reg         Lvl
# 19      20          20       RL     7560   Pave      Reg         Lvl
# 20      21          60       RL    14215   Pave      IR1         Lvl
# 21      22          45       RM     7449   Pave      Reg         Bnk
# 22      23          20       RL     9742   Pave      Reg         Lvl
# 23      24         120       RM     4224   Pave      Reg         Lvl
# 24      25          20       RL     8246   Pave      IR1         Lvl
# 25      26          20       RL    14230   Pave      Reg         Lvl
# 26      27          20       RL     7200   Pave      Reg         Lvl
# 27      28          20       RL    11478   Pave      Reg         Lvl
# 28      29          20       RL    16321   Pave      IR1         Lvl
# 29      30          30       RM     6324   Pave      IR1         Lvl
# 30      31          70  C (all)     8500   Pave      Reg         Lvl
# 31      32          20       RL     8544   Pave      IR1         Lvl
# 32      33          20       RL    11049   Pave      Reg         Lvl
# 33      34          20       RL    10552   Pave      IR1         Lvl
# 34      35         120       RL     7313   Pave      Reg         Lvl
# 35      36          60       RL    13418   Pave      Reg         Lvl
# 36      37          20       RL    10859   Pave      Reg         Lvl
# 37      38          20       RL     8532   Pave      Reg         Lvl
# 38      39          20       RL     7922   Pave      Reg         Lvl
# 39      40          90       RL     6040   Pave      Reg         Lvl
# 40      41          20       RL     8658   Pave      Reg         Lvl
# 41      42          20       RL    16905   Pave      Reg         Lvl
# 42      43          85       RL     9180   Pave      IR1         Lvl
# 43      44          20       RL     9200   Pave      IR1         Lvl
# 44      45          20       RL     7945   Pave      Reg         Lvl
# 45      46         120       RL     7658   Pave      Reg         Lvl
# 46      47          50       RL    12822   Pave      IR1         Lvl
# 47      48          20       FV    11096   Pave      Reg         Lvl
# 48      49         190       RM     4456   Pave      Reg         Lvl
# 49      50          20       RL     7742   Pave      Reg         Lvl
# 50      51          60       RL    13869   Pave      IR2         Lvl
# 51      52          50       RM     6240   Pave      Reg         Lvl
# 52      53          90       RM     8472   Grvl      IR2         Bnk
# 53      54          20       RL    50271   Pave      IR1         Low
# 54      55          80       RL     7134   Pave      Reg         Bnk
# 55      56          20       RL    10175   Pave      IR1         Lvl
# 56      57         160       FV     2645   Pave      Reg         Lvl
# 57      58          60       RL    11645   Pave      IR1         Lvl
# 58      59          60       RL    13682   Pave      IR2         HLS
# 59      60          20       RL     7200   Pave      Reg         Bnk
# 60      61          20       RL    13072   Pave      Reg         Lvl
# 61      62          75       RM     7200   Pave      Reg         Lvl
# 62      63         120       RL     6442   Pave      IR1         Lvl
# 63      64          70       RM    10300   Pave      IR1         Bnk
# 64      65          60       RL     9375   Pave      Reg         Lvl
# 65      66          60       RL     9591   Pave      Reg         Lvl
# 66      67          20       RL    19900   Pave      Reg         Lvl
# 67      68          20       RL    10665   Pave      IR1         Lvl
# 68      69          30       RM     4608   Pave      Reg         Lvl
# 69      70          50       RL    15593   Pave      Reg         Lvl
# 70      71          20       RL    13651   Pave      IR1         Lvl
# 71      72          20       RL     7599   Pave      Reg         Lvl
# 72      73          60       RL    10141   Pave      IR1         Lvl
# 73      74          20       RL    10200   Pave      Reg         Lvl
# 74      75          50       RM     5790   Pave      Reg         Lvl
# 75      76         180       RM     1596   Pave      Reg         Lvl
# 76      77          20       RL     8475   Pave      IR1         Lvl
# 77      78          50       RM     8635   Pave      Reg         Lvl
# 78      79          90       RL    10778   Pave      Reg         Lvl
# 79      80          50       RM    10440   Pave      Reg         Lvl
# 80      81          60       RL    13000   Pave      Reg         Lvl
# 81      82         120       RM     4500   Pave      Reg         Lvl
# 82      83          20       RL    10206   Pave      Reg         Lvl
# 83      84          20       RL     8892   Pave      IR1         Lvl
# 84      85          80       RL     8530   Pave      IR1         Lvl
# 85      86          60       RL    16059   Pave      Reg         Lvl
# 86      87          60       RL    11911   Pave      IR2         Lvl
# 87      88         160       FV     3951   Pave      Reg         Lvl
# 88      89          50  C (all)     8470   Pave      IR1         Lvl
# 89      90          20       RL     8070   Pave      Reg         Lvl
# 90      91          20       RL     7200   Pave      Reg         Lvl
# 91      92          20       RL     8500   Pave      Reg         Lvl
# 92      93          30       RL    13360   Pave      IR1         HLS
# 93      94         190  C (all)     7200   Pave      Reg         Lvl
# 94      95          60       RL     9337   Pave      IR1         Lvl
# 95      96          60       RL     9765   Pave      IR2         Lvl
# 96      97          20       RL    10264   Pave      IR1         Lvl
# 97      98          20       RL    10921   Pave      Reg         HLS
# 98      99          30       RL    10625   Pave      Reg         Lvl
# 99     100          20       RL     9320   Pave      IR1         Lvl
# 100    101          20       RL    10603   Pave      IR1         Lvl
# 101    102          60       RL     9206   Pave      Reg         Lvl
# 102    103          90       RL     7018   Pave      Reg         Bnk
# 103    104          20       RL    10402   Pave      IR1         Lvl
# 104    105          50       RM     7758   Pave      Reg         Lvl
# 105    106          60       FV     9375   Pave      Reg         Lvl
# 106    107          30       RM    10800   Pave      Reg         Lvl
# 107    108          20       RM     6000   Pave      Reg         Lvl
# 108    109          50       RM     8500   Pave      Reg         Lvl
# 109    110          20       RL    11751   Pave      IR1         Lvl
# 110    111          50       RL     9525   Pave      Reg         Lvl
# 111    112          80       RL     7750   Pave      IR1         Lvl
# 112    113          60       RL     9965   Pave      Reg         Lvl
# 113    114          20       RL    21000   Pave      Reg         Bnk
# 114    115          70       RL     7259   Pave      IR1         Lvl
# 115    116         160       FV     3230   Pave      Reg         Lvl
# 116    117          20       RL    11616   Pave      Reg         Lvl
# 117    118          20       RL     8536   Pave      Reg         Lvl
# 118    119          60       RL    12376   Pave      Reg         Lvl
# 119    120          60       RL     8461   Pave      Reg         Lvl
# 120    121          80       RL    21453   Pave      IR1         Low
# 121    122          50       RM     6060   Pave      Reg         Lvl
# 122    123          20       RL     9464   Pave      Reg         Lvl
# 123    124         120       RL     7892   Pave      Reg         Lvl
# 124    125          20       RL    17043   Pave      IR1         Lvl
# 125    126         190       RM     6780   Pave      Reg         Lvl
# 126    127         120       RL     4928   Pave      IR1         Lvl
# 127    128          45       RM     4388   Pave      IR1         Bnk
# 128    129          60       RL     7590   Pave      Reg         Lvl
# 129    130          20       RL     8973   Pave      Reg         Lvl
# 130    131          60       RL    14200   Pave      Reg         Lvl
# 131    132          60       RL    12224   Pave      IR1         Lvl
# 132    133          20       RL     7388   Pave      Reg         Lvl
# 133    134          20       RL     6853   Pave      IR1         Lvl
# 134    135          20       RL    10335   Pave      IR1         Lvl
# 135    136          20       RL    10400   Pave      Reg         Lvl
# 136    137          20       RL    10355   Pave      IR1         Lvl
# 137    138          90       RL    11070   Pave      Reg         Lvl
# 138    139          60       RL     9066   Pave      IR1         Lvl
# 139    140          60       RL    15426   Pave      IR1         Lvl
# 140    141          20       RL    10500   Pave      Reg         Lvl
# 141    142          20       RL    11645   Pave      Reg         Lvl
# 142    143          50       RL     8520   Pave      Reg         Lvl
# 143    144          20       RL    10335   Pave      IR1         Lvl
# 144    145          90       RM     9100   Pave      Reg         Lvl
# 145    146         160       RM     2522   Pave      Reg         Lvl
# 146    147          30       RM     6120   Pave      Reg         Lvl
# 147    148          60       RL     9505   Pave      IR1         Lvl
# 148    149          20       RL     7500   Pave      Reg         Lvl
# 149    150          50       RM     6240   Pave      Reg         Lvl
# 150    151          20       RL    10356   Pave      Reg         Lvl
# 151    152          20       RL    13891   Pave      Reg         Lvl
# 152    153          60       RL    14803   Pave      IR1         Lvl
# 153    154          20       RL    13500   Pave      Reg         Lvl
# 154    155          30       RM    11340   Pave      Reg         Lvl
# 155    156          50       RL     9600   Pave      Reg         Lvl
# 156    157          20       RL     7200   Pave      Reg         Lvl
# 157    158          60       RL    12003   Pave      Reg         Lvl
# 158    159          60       FV    12552   Pave      Reg         Lvl
# 159    160          60       RL    19378   Pave      IR1         HLS
# 160    161          20       RL    11120   Pave      IR1         Lvl
# 161    162          60       RL    13688   Pave      IR1         Lvl
# 162    163          20       RL    12182   Pave      Reg         Lvl
# 163    164          45       RL     5500   Pave      Reg         Lvl
# 164    165          40       RM     5400   Pave      Reg         Lvl
# 165    166         190       RL    10106   Pave      Reg         Lvl
# 166    167          20       RL    10708   Pave      IR1         Lvl
# 167    168          60       RL    10562   Pave      Reg         Lvl
# 168    169          60       RL     8244   Pave      IR1         Lvl
# 169    170          20       RL    16669   Pave      IR1         Lvl
# 170    171          50       RM    12358   Pave      IR1         Lvl
# 171    172          20       RL    31770   Pave      IR1         Lvl
# 172    173         160       RL     5306   Pave      IR1         Lvl
# 173    174          20       RL    10197   Pave      IR1         Lvl
# 174    175          20       RL    12416   Pave      IR1         Lvl
# 175    176          20       RL    12615   Pave      Reg         Lvl
# 176    177          60       RL    10029   Pave      IR1         Lvl
# 177    178          50       RL    13650   Pave      Reg         Lvl
# 178    179          20       RL    17423   Pave      IR1         Lvl
# 179    180          30       RM     8520   Pave      Reg         Lvl
# 180    181         160       FV     2117   Pave      Reg         Lvl
# 181    182          70       RL     7588   Pave      Reg         Lvl
# 182    183          20       RL     9060   Pave      Reg         Lvl
# 183    184          50       RM    11426   Pave      Reg         Lvl
# 184    185          50       RL     7438   Pave      IR1         Lvl
# 185    186          75       RM    22950   Pave      IR2         Lvl
# 186    187          80       RL     9947   Pave      IR1         Lvl
# 187    188          50       RL    10410   Pave      Reg         Lvl
# 188    189          90       RL     7018   Pave      Reg         Bnk
# 189    190         120       RL     4923   Pave      Reg         Lvl
# 190    191          70       RL    10570   Pave      Reg         Bnk
# 191    192          60       RL     7472   Pave      IR1         Lvl
# 192    193          20       RL     9017   Pave      IR1         Lvl
# 193    194         160       RM     2522   Pave      Reg         Lvl
# 194    195          20       RL     7180   Pave      IR1         Lvl
# 195    196         160       RL     2280   Pave      Reg         Lvl
# 196    197          20       RL     9416   Pave      Reg         Lvl
# 197    198          75       RL    25419   Pave      Reg         Lvl
# 198    199          75       RM     5520   Pave      Reg         Lvl
# 199    200          20       RL     9591   Pave      Reg         Lvl
# 200    201          20       RM     8546   Pave      Reg         Lvl
# 201    202          20       RL    10125   Pave      Reg         Lvl
# 202    203          50       RL     7000   Pave      Reg         Lvl
# 203    204         120       RM     4438   Pave      Reg         Lvl
# 204    205          50       RM     3500   Pave      Reg         Lvl
# 205    206          20       RL    11851   Pave      Reg         Lvl
# 206    207          20       RL    13673   Pave      IR1         Lvl
# 207    208          20       RL    12493   Pave      IR1         Lvl
# 208    209          60       RL    14364   Pave      IR1         Low
# 209    210          20       RL     8250   Pave      Reg         Lvl
# 210    211          30       RL     5604   Pave      Reg         Lvl
# 211    212          20       RL    10420   Pave      Reg         Lvl
# 212    213          60       FV     8640   Pave      Reg         Lvl
# 213    214          20       RL    13568   Pave      IR2         Lvl
# 214    215          60       RL    10900   Pave      IR1         Lvl
# 215    216          20       RL    10011   Pave      IR1         Lvl
# 216    217          20       RL     8450   Pave      Reg         Lvl
# 217    218          70       RM     9906   Pave      Reg         Lvl
# 218    219          50       RL    15660   Pave      IR1         Lvl
# 219    220         120       RL     3010   Pave      Reg         Lvl
# 220    221          20       RL     8990   Pave      IR1         Lvl
# 221    222          60       RL     8068   Pave      IR1         Lvl
# 222    223          60       RL    11475   Pave      Reg         Lvl
# 223    224          20       RL    10500   Pave      Reg         Lvl
# 224    225          20       RL    13472   Pave      Reg         Lvl
# 225    226         160       RM     1680   Pave      Reg         Lvl
# 226    227          60       RL     9950   Pave      IR1         Lvl
# 227    228         160       RM     1869   Pave      Reg         Lvl
# 228    229          20       RL     8521   Pave      Reg         Lvl
# 229    230         120       RL     3182   Pave      Reg         Lvl
# 230    231          20       RL     8760   Pave      Reg         Lvl
# 231    232          60       RL    15138   Pave      IR1         Lvl
# 232    233         160       RM     1680   Pave      Reg         Lvl
# 233    234          20       RL    10650   Pave      Reg         Lvl
# 234    235          60       RL     7851   Pave      Reg         Lvl
# 235    236         160       RM     1680   Pave      Reg         Lvl
# 236    237          20       RL     8773   Pave      Reg         Lvl
# 237    238          60       RL     9453   Pave      IR1         Lvl
# 238    239          20       RL    12030   Pave      Reg         Lvl
# 239    240          50       RL     8741   Pave      Reg         Lvl
# 240    241          20       FV     9000   Pave      Reg         Lvl
# 241    242          30       RM     3880   Pave      Reg         Lvl
# 242    243          50       RM     5000   Pave      Reg         Lvl
# 243    244         160       RL    10762   Pave      Reg         Lvl
# 244    245          60       RL     8880   Pave      IR1         Lvl
# 245    246          20       RL    10400   Pave      Reg         Lvl
# 246    247         190       RM     9142   Pave      Reg         Lvl
# 247    248          20       RL    11310   Pave      Reg         Lvl
# 248    249          60       RL    11317   Pave      Reg         Lvl
# 249    250          50       RL   159000   Pave      IR2         Low
# ...    ...         ...      ...      ...    ...      ...         ...
# 1210  1211          60       RL    11218   Pave      Reg         Lvl
# 1211  1212          50       RL    12134   Pave      IR1         Bnk
# 1212  1213          30       RL     9340   Pave      Reg         Lvl
# 1213  1214          80       RL    10246   Pave      IR1         Lvl
# 1214  1215          85       RL    10205   Pave      IR1         Lvl
# 1215  1216          20       RL     7094   Pave      IR1         Lvl
# 1216  1217          90       RM     8930   Pave      Reg         Lvl
# 1217  1218          20       FV     8640   Pave      Reg         Lvl
# 1218  1219          50       RM     6240   Pave      Reg         Lvl
# 1219  1220         160       RM     1680   Pave      Reg         Lvl
# 1220  1221          20       RL     7800   Pave      IR1         Lvl
# 1221  1222          20       RL     8250   Pave      Reg         Lvl
# 1222  1223          50       RL    10496   Pave      Reg         Lvl
# 1223  1224          20       RL    10680   Pave      Reg         Lvl
# 1224  1225          60       RL    15384   Pave      IR1         Lvl
# 1225  1226          80       RL    10482   Pave      Reg         Lvl
# 1226  1227          60       RL    14598   Pave      IR1         Lvl
# 1227  1228          20       RL     8872   Pave      Reg         Lvl
# 1228  1229         120       RL     8769   Pave      Reg         Lvl
# 1229  1230          80       RL     7910   Pave      Reg         Lvl
# 1230  1231          90       RL    18890   Pave      IR1         Lvl
# 1231  1232          90       RL     7728   Pave      Reg         Lvl
# 1232  1233          90       RL     9842   Pave      Reg         Lvl
# 1233  1234          20       RL    12160   Pave      IR1         Lvl
# 1234  1235          70       RH     8525   Pave      Reg         Bnk
# 1235  1236          70       RL    13132   Pave      Reg         Lvl
# 1236  1237         160       RL     2628   Pave      Reg         Lvl
# 1237  1238          60       RL    12393   Pave      IR2         Lvl
# 1238  1239          20       RL    13072   Pave      Reg         Lvl
# 1239  1240          20       RL     9037   Pave      IR1         HLS
# 1240  1241          60       RL     8158   Pave      Reg         Lvl
# 1241  1242          20       RL     9849   Pave      Reg         Lvl
# 1242  1243          85       RL    10625   Pave      Reg         Lvl
# 1243  1244          20       RL    13891   Pave      Reg         Lvl
# 1244  1245          70       RL    11435   Pave      IR1         HLS
# 1245  1246          80       RL    12090   Pave      Reg         Lvl
# 1246  1247          60       FV     8125   Pave      Reg         Lvl
# 1247  1248          80       RL    12328   Pave      IR1         Lvl
# 1248  1249          75       RM     9600   Pave      Reg         Lvl
# 1249  1250          20       RL     7200   Pave      Reg         Lvl
llPub    Inside       Gtl      CollgCr       Norm       Norm
# 3       AllPub    Corner       Gtl      Crawfor       Norm       Norm
# 4       AllPub       FR2       Gtl      NoRidge       Norm       Norm
# 5       AllPub    Inside       Gtl      Mitchel       Norm       Norm
# 6       AllPub    Inside       Gtl      Somerst       Norm       Norm
# 7       AllPub    Corner       Gtl       NWAmes       PosN       Norm
# 8       AllPub    Inside       Gtl      OldTown     Artery       Norm
# 9       AllPub    Corner       Gtl      BrkSide     Artery     Artery
# 10      AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 11      AllPub    Inside       Gtl      NridgHt       Norm       Norm
# 12      AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 13      AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 14      AllPub    Corner       Gtl        NAmes       Norm       Norm
# 15      AllPub    Corner       Gtl      BrkSide       Norm       Norm
# 16      AllPub   CulDSac       Gtl        NAmes       Norm       Norm
# 17      AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 18      AllPub    Inside       Gtl      SawyerW       RRAe       Norm
# 19      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 20      AllPub    Corner       Gtl      NridgHt       Norm       Norm
# 21      AllPub    Inside       Gtl       IDOTRR       Norm       Norm
# 22      AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 23      AllPub    Inside       Gtl      MeadowV       Norm       Norm
# 24      AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 25      AllPub    Corner       Gtl      NridgHt       Norm       Norm
# 26      AllPub    Corner       Gtl        NAmes       Norm       Norm
# 27      AllPub    Inside       Gtl      NridgHt       Norm       Norm
# 28      AllPub   CulDSac       Gtl        NAmes       Norm       Norm
# 29      AllPub    Inside       Gtl      BrkSide      Feedr       RRNn
# 30      AllPub    Inside       Gtl       IDOTRR      Feedr       Norm
# 31      AllPub   CulDSac       Gtl       Sawyer       Norm       Norm
# 32      AllPub    Corner       Gtl      CollgCr       Norm       Norm
# 33      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 34      AllPub    Inside       Gtl      NridgHt       Norm       Norm
# 35      AllPub    Inside       Gtl      NridgHt       Norm       Norm
# 36      AllPub    Corner       Gtl      CollgCr       Norm       Norm
# 37      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 38      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 39      AllPub    Inside       Gtl      Edwards       Norm       Norm
# 40      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 41      AllPub    Inside       Gtl       Timber       Norm       Norm
# 42      AllPub   CulDSac       Gtl      SawyerW       Norm       Norm
# 43      AllPub   CulDSac       Gtl      CollgCr       Norm       Norm
# 44      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 45      AllPub    Inside       Gtl      NridgHt       Norm       Norm
# 46      AllPub   CulDSac       Gtl      Mitchel       Norm       Norm
# 47      AllPub    Inside       Gtl      Somerst       Norm       Norm
# 48      AllPub    Inside       Gtl      OldTown       Norm       Norm
# 49      AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 50      AllPub    Corner       Gtl      Gilbert       Norm       Norm
# 51      AllPub    Inside       Gtl      BrkSide       Norm       Norm
# 52      AllPub    Corner       Mod       IDOTRR       RRNn       Norm
# 53      AllPub    Inside       Gtl      Veenker       Norm       Norm
# 54      AllPub    Inside       Mod        NAmes       Norm       Norm
# 55      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 56      AllPub    Inside       Gtl      Somerst       Norm       Norm
# 57      AllPub    Corner       Gtl      CollgCr       Norm       Norm
# 58      AllPub   CulDSac       Gtl      StoneBr       Norm       Norm
# 59      AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 60      AllPub    Inside       Gtl      SawyerW       RRAe       Norm
# 61      AllPub    Inside       Gtl       IDOTRR       Norm       Norm
# 62      AllPub    Inside       Gtl      NridgHt       Norm       Norm
# 63      AllPub    Inside       Gtl      OldTown       RRAn      Feedr
# 64      AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 65      AllPub    Inside       Gtl      NridgHt       Norm       Norm
# 66      AllPub    Inside       Gtl        NAmes       PosA       Norm
# 67      AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 68      AllPub    Corner       Gtl      OldTown     Artery       Norm
# 69      AllPub    Corner       Gtl      ClearCr       Norm       Norm
# 70      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 71      AllPub    Corner       Gtl      Mitchel       Norm       Norm
# 72      AllPub    Corner       Gtl      Gilbert       Norm       Norm
# 73      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 74      AllPub    Corner       Gtl      OldTown       Norm       Norm
# 75      AllPub    Inside       Gtl      MeadowV       Norm       Norm
# 76      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 77      AllPub    Inside       Gtl      BrkSide       Norm       Norm
# 78      AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 79      AllPub    Corner       Gtl      OldTown       Norm       Norm
# 80      AllPub    Corner       Gtl        NAmes       Norm       Norm
# 81      AllPub       FR2       Gtl      Mitchel       Norm       Norm
# 82      AllPub    Inside       Gtl      Somerst       Norm       Norm
# 83      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 84      AllPub    Inside       Gtl      Gilbert       Norm       Norm
# 85      AllPub    Corner       Gtl      NoRidge       Norm       Norm
# 86      AllPub    Inside       Gtl      Gilbert       Norm       Norm
# 87      AllPub    Corner       Gtl      Somerst       Norm       Norm
# 88      AllPub    Corner       Gtl       IDOTRR      Feedr      Feedr
# 89      AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 90      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 91      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 92      AllPub    Inside       Gtl      Crawfor       Norm       Norm
# 93      AllPub    Corner       Gtl      OldTown       Norm       Norm
# 94      AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 95      AllPub    Corner       Gtl      Gilbert       Norm       Norm
# 96      AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 97      AllPub    Inside       Gtl      Edwards       Norm       Norm
# 98      AllPub    Corner       Gtl      Edwards       Norm       Norm
# 99      AllPub    Inside       Gtl        NAmes       Norm       Norm
# 100     AllPub    Inside       Gtl       NWAmes       Norm       Norm
# 101     AllPub    Inside       Gtl      SawyerW       Norm       Norm
# 102     AllPub    Inside       Gtl      SawyerW       Norm       Norm
# 103     AllPub    Corner       Gtl      CollgCr       Norm       Norm
# 104     AllPub    Corner       Gtl       IDOTRR       Norm       Norm
# 105     AllPub    Inside       Gtl      Somerst       Norm       Norm
# 106     AllPub    Inside       Gtl      OldTown       Norm       Norm
# 107     AllPub    Inside       Gtl      OldTown       Norm       Norm
# 108     AllPub    Corner       Gtl       IDOTRR     Artery       Norm
# 109     AllPub    Inside       Gtl       NWAmes       Norm       Norm
# 110     AllPub    Inside       Gtl      Edwards       Norm       Norm
# 111     AllPub    Inside       Gtl      Gilbert       Norm       Norm
# 112     AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 113     AllPub    Corner       Gtl      Crawfor       Norm       Norm
# 114     AllPub    Inside       Mod      Crawfor       Norm       Norm
# 115     AllPub    Corner       Gtl      Somerst       Norm       Norm
# 116     AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 117     AllPub    Corner       Gtl      Edwards       Norm       Norm
# 118     AllPub    Corner       Gtl      SawyerW       Norm       Norm
# 119     AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 120     AllPub   CulDSac       Sev      ClearCr       Norm       Norm
# 121     AllPub    Inside       Gtl       IDOTRR       Norm       Norm
# 122     AllPub    Corner       Gtl        NAmes       Norm       Norm
# 123     AllPub    Inside       Gtl      SawyerW       Norm       Norm
# 124     AllPub   CulDSac       Gtl       NWAmes       Norm       Norm
# 125     AllPub    Inside       Gtl       IDOTRR       Norm       Norm
# 126     AllPub    Inside       Gtl      NPkVill       Norm       Norm
# 127     AllPub    Inside       Gtl      OldTown      Feedr       Norm
# 128     AllPub    Inside       Gtl        NAmes       PosN       Norm
# 129     AllPub    Inside       Gtl        NAmes       Norm       Norm
# 130     AllPub    Corner       Gtl        NAmes       Norm       Norm
# 131     AllPub    Corner       Gtl      Gilbert       Norm       Norm
# 132     AllPub    Corner       Gtl        NAmes       Norm       Norm
# 133     AllPub    Inside       Gtl       Timber       Norm       Norm
# 134     AllPub    Inside       Gtl       Sawyer       Norm       Norm
# 135     AllPub    Inside       Gtl       NWAmes       Norm       Norm
# 136     AllPub    Corner       Gtl        NAmes       Norm       Norm
# 137     AllPub    Inside       Gtl      Mitchel       Norm       Norm
# 138     AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 139     AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 140     AllPub       FR2       Gtl        NAmes       Norm       Norm
# 141     AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 142     AllPub    Corner       Gtl        NAmes     Artery       Norm
# 143     AllPub    Inside       Gtl      CollgCr       Norm       Norm
# 144     AllPub    Inside       Gtl       Sawyer       RRAe       Norm
# 145     AllPub    Inside       Gtl      Edwards       Norm       Norm
# 146     AllPub    Corner       Gtl      BrkSide       Norm       Norm
# 147     AllPub   CulDSac       Gtl      Gilbert       Norm       Norm
# 148     AllPub    Inside       Gtl      SawyerW       Norm       Norm
# 149     AllPub    Inside       Gtl      BrkSide       Norm       Norm
# 150     AllPub    Corner       Gtl      CollgCr       Norm       Norm
# 151     AllPub    Inside       Gtl      NridgHt       Norm       Norm
# 152     AllPub   CulDSac       Gtl       NWAmes       Norm       Norm
# 153     AllPub    Inside       Gtl      ClearCr       Norm       Norm
# 154     AllPub    Corner       Gtl      OldTown       Norm       Norm
# 155     AllPub    Corner       Gtl      Edwards     Artery       Norm
# 156     AllPub    Inside       Gtl        NAmes       Norm       Norm
# 157     AllPub    Corner       Gtl       Timber       Norm       Norm
# 158     AllPub    Corner       Gtl      Somerst       Norm       Norm
# 159     AllPub    Corner       Gtl      Gilbert       Norm       Norm
# 160     AllPub   CulDSac       Gtl      Veenker       Norm       Norm
# ...
# 175     2007       WD        Normal     243000
# 176     2007       WD        Normal     211000
# 177     2006       WD        Normal     172500
# 178     2009      New       Partial     501837
# 179     2007       WD        Normal     100000
# 180     2007       WD        Normal     177000
# 181     2006       WD        Normal     200100
# 182     2007       WD        Normal     120000
# 183     2008       WD        Normal     200000
# 184     2006       WD        Normal     127000
# 185     2006       WD        Normal     475000
# 186     2009       WD        Normal     173000
# 187     2009       WD        Normal     135000
# 188     2009       WD        Alloca     153337
# 189     2008       WD        Normal     286000
# 190     2007       WD        Normal     315000
# 191     2007       WD        Normal     184000
# 192     2009       WD        Normal     192000
# 193     2006       WD        Normal     130000
# 194     2008       WD        Normal     127000
# 195     2009       WD        Normal     148500
# 196     2007      New       Partial     311872
# 197     2006       WD       Abnorml     235000
# 198     2009       WD       Abnorml     104000
# 199     2009       WD        Normal     274900
# 200     2010       WD        Normal     140000
# 201     2008       WD        Normal     171500
# 202     2006      COD        Normal     112000
# 203     2008       WD        Normal     149000
# 204     2009       WD        Normal     110000
# 205     2009       WD        Normal     180500
# 206     2007       WD        Normal     143900
# 207     2008       WD        Normal     141000
# 208     2007       WD        Normal     277000
# 209     2008       WD        Normal     145000
# 210     2008       WD        Normal      98000
# 211     2010       WD        Normal     186000
# 212     2009      New       Partial     252678
# 213     2006       WD        Normal     156000
# 214     2010       WD        Normal     161750
# 215     2006       WD        Normal     134450
# 216     2008       WD        Normal     210000
# 217     2006       WD        Family     107000
# 218     2008       WD        Normal     311500
# 219     2006      New       Partial     167240
# 220     2006      New       Partial     204900
# 221     2009    ConLI        Normal     200000
# 222     2006       WD        Normal     179900
# 223     2009       WD       Abnorml      97000
# 224     2009       WD        Normal     386250
# 225     2009      COD       Abnorml     112000
# 226     2007       WD       Abnorml     290000
# 227     2008       WD        Normal     106000
# 228     2010       WD        Normal     125000
# 229     2009       WD        Normal     192500
# 230     2010       WD        Normal     148000
# 231     2009       WD        Normal     403000
# 232     2006       WD        Normal      94500
# 233     2010       WD        Normal     128200
# 234     2010       WD        Normal     216500
# 235     2008       WD        Normal      89500
# 236     2010       WD        Normal     185500
# 237     2010       WD        Normal     194500
# 238     2007      New       Partial     318000
# 239     2010       WD        Normal     113000
# 240     2010       WD        Normal     262500
# 241     2007       WD        Normal     110500
# 242     2006       WD        Normal      79000
# 243     2009       WD        Normal     120000
# 244     2010       WD        Normal     205000
# 245     2006       WD        Normal     241500
# 246     2006       WD        Normal     137000
# 247     2006       WD        Normal     140000
# 248     2007       WD        Normal     180000
# 249     2007       WD        Normal     277000
# ...      ...      ...           ...        ...
# 1210    2010       WD        Normal     189000
# 1211    2010       WD        Normal     164000
# 1212    2009       WD        Normal     113000
# 1213    2006       WD        Normal     145000
# 1214    2006       WD        Normal     134500
# 1215    2007       WD        Normal     125000
# 1216    2010       WD        Normal     112000
# 1217    2009      New       Partial     229456
# 1218    2006       WD        Normal      80500
# 1219    2006       WD       Abnorml      91500
# 1220    2006       WD       Abnorml     115000
# 1221    2008       WD        Normal     134000
# 1222    2007       WD        Normal     143000
# 1223    2006       WD        Normal     137900
# 1224    2008       WD        Normal     184000
# 1225    2007       WD        Normal     145000
# 1226    2008       WD        Normal     214000
# 1227    2008       WD        Normal     147000
# 1228    2008      New       Partial     367294
# 1229    2008       WD        Normal     127000
# 1230    2007       WD        Normal     190000
# 1231    2006       WD        Normal     132500
# 1232    2007       WD        Normal     101800
# 1233    2010      COD       Abnorml     142000
# 1234    2008       WD       Abnorml     130000
# 1235    2006       WD        Normal     138887
# 1236    2010       WD        Normal     175500
# 1237    2006       WD        Normal     195000
# 1238    2006       WD       Abnorml     142500
# 1239    2007       WD        Normal     265900
# 1240    2008       WD        Normal     224900
# 1241    2007      New       Partial     248328
# 1242    2010       WD        Family     170000
# 1243    2006      New       Partial     465000
# 1244    2006       WD        Normal     230000
# 1245    2007       WD       Abnorml     178000
# 1246    2006      New       Partial     186500
# 1247    2010       WD        Normal     169900
# 1248    2008       WD        Normal     129500
# 1249    2007       WD        Normal     119000
# 1250    2010       WD        Normal     244000
# 1251    2006       WD        Normal     171750
# 1252    2009       WD        Normal     130000
# 1253    2007       WD        Normal     294000
# 1254    2008       WD        Normal     165400
# 1255    2007       WD        Normal     127500
# 1256    2008       WD        Normal     301500
# 1257    2009       WD        Normal      99900
# 1258    2008       WD        Normal     190000
# 1259    2008       WD        Normal     151000
# 1260    2009       WD        Normal     181000
# 1261    2009       WD        Normal     128900
# 1262    2009       WD        Normal     161500
# 1263    2007       WD        Normal     180500
# 1264    2008      COD       Abnorml     181000
# 1265    2006       WD        Normal     183900
# 1266    2007       WD        Normal     122000
# 1267    2010       WD        Normal     378500
# 1268    2008       WD        Normal     381000
# 1269    2007       WD        Normal     144000
# 1270    2010       WD        Normal     260000
# 1271    2009       WD        Normal     185750
# 1272    2006       WD        Normal     137000
# 1273    2008       WD        Normal     177000
# 1274    2007       WD        Normal     139000
# 1275    2007       WD        Normal     137000
# 1276    2009       WD        Normal     162000
# 1277    2009       WD        Normal     197900
# 1278    2008       WD        Normal     237000
# 1279    2010      COD       Abnorml      68400
# 1280    2009       WD        Normal     227000
# 1281    2006       WD        Normal     180000
# 1282    2009       WD        Normal     150500
# 1283    2010       WD        Normal     139000
# 1284    2010       WD        Normal     169000
# 1285    2009       WD        Normal     132500
# 1286    2010       WD        Normal     143000
# 1287    2006       WD        Normal     190000
# 1288    2009       WD        Normal     278000
# 1289    2006      New       Partial     281000
# 1290    2010       WD        Normal     180500
# 1291    2009       WD        Normal     119500
# 1292    2009       WD        Normal     107500
# 1293    2006       WD        Normal     162900
# 1294    2006       WD        Normal     115000
# 1295    2006       WD        Normal     138500
# 1296    2008       WD        Normal     155000
# 1297    2006      New       Partial     140000
# 1298    2008      New       Partial     160000
# 1299    2010       WD        Normal     154000
# 1300    2009       WD        Normal     225000
# 1301    2009       WD        Normal     177500
# 1302    2006       WD        Normal     290000
# 1303    2006       WD        Normal     232000
# 1304    2006       WD        Normal     130000
# 1305    2009       WD        Normal     325000
# 1306    2006      New       Partial     202500
# 1307    2009       WD        Normal     138000
# 1308    2008       WD        Normal     147000
# 1309    2008       WD        Normal     179200
# 1310    2010       WD        Normal     335000
# 1311    2007      New       Partial     203000
# 1312    2007       WD        Normal     302000
# 1313    2010       WD        Normal     333168
# 1314    2007       WD        Normal     119000
# 1315    2008       WD        Normal     206900
# 1316    2009       WD        Normal     295493
# 1317    2007      New       Partial     208900
# 1318    2006       WD        Normal     275000
# 1319    2007       WD        Normal     111000
# 1320    2009       WD        Normal     156500
# 1321    2008       WD        Normal      72500
# 1322    2010       WD        Normal     190000
# 1323    2009       WD        Normal      82500
# 1324    2007      New       Partial     147000
# 1325    2008       WD        Normal      55000
# 1326    2007       WD        Normal      79000
# 1327    2008       WD        Normal     130500
# 1328    2008       WD        Normal     256000
# 1329    2006       WD        Normal     176500
# 1330    2007       WD        Normal     227000
# 1331    2006       WD        Normal     132500
# 1332    2009       WD        Normal     100000
# 1333    2006       WD        Normal     125500
# 1334    2009       WD        Normal     125000
# 1335    2009       WD        Normal     167900
# 1336    2008       WD        Normal     135000
# 1337    2006       WD        Normal      52500
# 1338    2006       WD        Normal     200000
# 1339    2006       WD        Normal     128500
# 1340    2007       WD        Normal     123000
# 1341    2008       WD        Normal     155000
# 1342    2007       WD        Normal     228500
# 1343    2009       WD        Normal     177000
# 1344    2007      New       Partial     155835
# 1345    2007       WD        Normal     108500
# 1346    2006       WD        Normal     262500
# 1347    2007      New       Partial     283463
# 1348    2007       WD        Normal     215000
# 1349    2008       WD        Normal     122000
# 1350    2009       WD        Normal     200000
# 1351    2008       WD        Normal     171000
# 1352    2009       WD        Normal     134900
# 1353    2010       WD        Normal     410000
# 1354    2008       WD        Normal     235000
# 1355    2006       WD        Normal     170000
# 1356    2008       WD        Normal     110000
# 1357    2010       WD        Normal     149900
# 1358    2010       WD        Normal     177500
# 1359    2006       WD        Normal     315000
# 1360    2008       WD        Normal     189000
# 1361    2009       WD        Normal     260000
# 1362    2009       WD        Normal     104900
# 1363    2007      New       Partial     156932
# 1364    2006       WD       Abnorml     144152
# 1365    2010       WD        Normal     216000
# 1366    2008       WD       Abnorml     193000
# 1367    2006       WD        Normal     127000
# 1368    2009       WD        Normal     144000
# 1369    2010       WD        Normal     232000
# 1370    2009       WD        Normal     105000
# 1371    2008       WD        Normal     165500
# 1372    2006       WD        Normal     274300
# 1373    2007       WD        Normal     466500
# 1374    2008       WD        Normal     250000
# 1375    2007      New       Partial     239000
# 1376    2008       WD        Normal      91000
# 1377    2009       WD        Normal     117000
# 1378    2006       WD        Normal      83000
# 1379    2008       WD        Normal     167500
# 1380    2010       WD        Normal      58500
# 1381    2008       WD        Normal     237500
# 1382    2006       WD        Normal     157000
# 1383    2007       WD        Normal     112000
# 1384    2009       WD        Normal     105000
# 1385    2010       WD        Normal     125500
# 1386    2006       WD        Normal     250000
# 1387    2007      CWD        Family     136000
# 1388    2009       WD        Normal     377500
# 1389    2007       WD        Normal     131000
# 1390    2006       WD        Normal     235000
# 1391    2009       WD        Normal     124000
# 1392    2006       WD        Normal     123000
# 1393    2008       WD        Normal     163000
# 1394    2006      New       Partial     246578
# 1395    2007       WD        Normal     281213
# 1396    2010       WD        Normal     160000
# 1397    2007       WD        Normal     137500
# 1398    2009       WD        Normal     138000
# 1399    2009       WD        Normal     137450
# 1400    2008       WD        Normal     120000
# 1401    2008       WD        Normal     193000
# 1402    2006      New       Partial     193879
# 1403    2007       WD        Normal     282922
# 1404    2006       WD        Family     105000
# 1405    2008       WD        Normal     275000
# 1406    2009       WD        Normal     133000
# 1407    2009       WD        Normal     112000
# 1408    2010       WD        Normal     125500
# 1409    2008       WD        Normal     215000
# 1410    2009       WD        Normal     230000
# 1411    2009       WD        Normal     140000
# 1412    2009       WD        Normal      90000
# 1413    2009      COD       Abnorml     257000
# 1414    2008       WD        Normal     207000
# 1415    2009       WD        Normal     175900
# 1416    2010       WD        Normal     122500
# 1417    2009       WD        Normal     340000
# 1418    2008      COD        Normal     124000
# 1419    2006       WD        Normal     223000
# 1420    2006       WD        Normal     179900
# 1421    2010       WD        Normal     127500
# 1422    2008       WD        Normal     136500
# 1423    2006       WD        Alloca     274970
# 1424    2007       WD        Normal     144000
# 1425    2008       WD        Normal     142000
# 1426    2008       WD        Normal     271000
# 1427    2008       WD        Normal     140000
# 1428    2010       WD       Abnorml     119000
# 1429    2007       WD        Normal     182900
# 1430    2006       WD        Normal     192140
# 1431    2009       WD        Normal     143750
# 1432    2007       WD        Normal      64500
# 1433    2008       WD        Normal     186500
# 1434    2006       WD        Normal     160000
# 1435    2008      COD       Abnorml     174000
# 1436    2007       WD        Normal     120500
# 1437    2008      New       Partial     394617
# 1438    2010       WD        Normal     149700
# 1439    2007       WD        Normal     197000
# 1440    2008       WD        Normal     191000
# 1441    2008       WD        Normal     149300
# 1442    2009       WD        Normal     310000
# 1443    2009       WD        Normal     121000
# 1444    2007       WD        Normal     179600
# 1445    2007       WD        Normal     129000
# 1446    2010       WD        Normal     157900
# 1447    2007       WD        Normal     240000
# 1448    2007       WD        Normal     112000
# 1449    2006       WD       Abnorml      92000
# 1450    2009       WD        Normal     136000
# 1451    2009      New       Partial     287090
# 1452    2006       WD        Normal     145000
# 1453    2006       WD       Abnorml      84500
# 1454    2009       WD        Normal     185000
# 1455    2007       WD        Normal     175000
# 1456    2010       WD        Normal     210000
# 1457    2010       WD        Normal     266500
# 1458    2010       WD        Normal     142125
# 1459    2008       WD        Normal     147500
#
# [1460 rows x 62 columns]

# %%
df_nums = df.select_dtypes(include=['float','int']).dropna(axis=1)

y = df_nums['SalePrice']
X = df_nums.drop(columns=['Id','SalePrice'])

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=42)

model = LinearRegression()
model.fit(X_train,y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
rmse = sqrt(mse)
r2 = r2_score(y_test,y_pred)

beta_0 = model.intercept_
beta_i = model.coef_

print('mean squared error: ', mse)
print('root mean squared error: ', rmse)
print('R squared: ', r2)
print('---------------------')
print('Intercept: ', beta_0)
print('Coefficients: ', beta_i)
# Out:
# mean squared error:  1392205606.2031894
# root mean squared error:  37312.27152296131
# R squared:  0.8184946026286748
# ---------------------
# Intercept:  -48411.54387291902
# Coefficients:  [-1.75548690e+02  4.09174234e-01  1.84955503e+04  3.83573710e+03
#   3.37312908e+02  1.80209917e+02  1.00461555e+01 -4.61607099e+00
#   3.82786747e-01  5.81287122e+00  1.31240039e+01  1.42134340e+01
#   4.50422890e+00  3.18416668e+01  1.10492803e+04 -3.26518493e+02
#   3.42606130e+03 -1.66531509e+03 -9.08810085e+03 -1.00971990e+04
#   5.10100134e+03  4.37021557e+03  1.16074917e+04  5.58607730e-01
#   2.55639049e+01 -6.62562003e+00  7.06908781e+00  3.85262374e+01
#   6.55989735e+01 -3.73443286e+01 -7.15692563e-01 -2.09433750e+02
#  -5.14524004e+02]

# %%
df['SaleCondition'].unique()
# Out:
# array(['Normal', 'Abnorml', 'Partial', 'AdjLand', 'Alloca', 'Family'],
#       dtype=object)

# %%
mask = {
    'Abnorml': 1, 
    'Partial': 2,
    'Normal': 3, 
    'AdjLand': 5,
    'Alloca': 4,
    'Family': 6,
}

df['SaleCondition'] = df['SaleCondition'].replace(mask,inplace=True)

# %%
print((df['Heating'].unique()))
print((df['HeatingQC'].unique()))
print((df['Foundation'].unique()))

foundations = {
    'PConc': 1,
    'CBlock': 1, 
    'BrkTil': 1,
    'Wood': 1,
    'Slab': 1, 
    'Stone': 1,
}
heating = {
    'Ex': 1,
    'Gd': 1,
    'TA': 1, 
    'Fa': 1,
    'Po': 1,
    
}
type_heating = {
    'GasA': 1,
    'GasW': 1, 
    'Grav': 1, 
    'Wall': 1,
    'OthW': 1,
    'Floor': 1
}
df['Ones_Foundation'] = df['Foundation'].replace(foundations)
df['Ones_HeatingQC'] = df['HeatingQC'].replace(heating)
df['Ones_Heating'] = df['Heating'].replace(type_heating)
# Out:
# [1]
# [1]
# [1]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-f124534a909d> in <module>
#      27     'Floor': 1
#      28 }
# ---> 29 df['Ones_HeatingQC'] = df['HeatingQC'].replace(heating,inplace=True)
#      30 df['Ones_Heating'] = df['Heating'].replace(type_heating,inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    3430         return super(Series, self).replace(to_replace=to_replace, value=value,
#    3431                                            inplace=inplace, limit=limit,
# -> 3432                                            regex=regex, method=method)
#    3433
#    3434     @Appender(generic._shared_docs['shift'] % _shared_doc_kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    5800
#    5801             return self.replace(to_replace, value, inplace=inplace,
# -> 5802                                 limit=limit, regex=regex)
#    5803         else:
#    5804
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    3430         return super(Series, self).replace(to_replace=to_replace, value=value,
#    3431                                            inplace=inplace, limit=limit,
# -> 3432                                            regex=regex, method=method)
#    3433
#    3434     @Appender(generic._shared_docs['shift'] % _shared_doc_kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    5849                                                        dest_list=value,
#    5850                                                        inplace=inplace,
# -> 5851                                                        regex=regex)
#    5852
#    5853                 else:  # [NA, ''] -> 0
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in replace_list(self, src_list, dest_list, inplace, regex, mgr)
#    3737             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3738
# -> 3739         masks = [comp(s) for i, s in enumerate(src_list)]
#    3740
#    3741         result_blocks = []
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in <listcomp>(.0)
#    3737             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3738
# -> 3739         masks = [comp(s) for i, s in enumerate(src_list)]
#    3740
#    3741         result_blocks = []
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in comp(s)
#    3735             if isna(s):
#    3736                 return isna(values)
# -> 3737             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3738
#    3739         masks = [comp(s) for i, s in enumerate(src_list)]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in _maybe_compare(a, b, op)
#    5163         raise TypeError(
#    5164             "Cannot compare types {a!r} and {b!r}".format(a=type_names[0],
# -> 5165                                                           b=type_names[1]))
#    5166     return result
#    5167
#
# TypeError: Cannot compare types 'ndarray(dtype=int64)' and 'str'

# %%
all_the_ones = ['Ones_Foundation','Ones_HeatingQC','Ones_Heating']

# %%
df['ln_price'] = np.log(df['SalePrice'])
df['N_Baths'] = df['BsmtFullBath'] + 0.5 * df['BsmtHalfBath'] + df['FullBath'] + 0.5 * df['HalfBath']
df['AboveGround'] = df['1stFlrSF'] + df['2ndFlrSF']
df['Sale_Weight_Condition'] = df['ln_price'] * df['SaleCondition']
df['Quality_Overall'] = np.divide((df['OverallQual'] * df['OverallCond']), ((df['YrSold'] - df['YearRemodAdd'])+df['YrSold']-df['YearBuilt']) + df['YearBuilt'])
df['Foundation_Weight'] = df['ln_price'] * df['Ones_Foundation']
df['HeatingQC_Weight'] = df['Ones_HeatingQC'] * df['ln_price']
df['HeatingType_Weight'] = df['Ones_Heating'] * df['ln_price']

# %%
## log
df_new = df.select_dtypes(include=['float','int']).dropna(axis=1)

y = df_new['ln_price']
X = df_new.drop(columns=['SalePrice','ln_price','Id',
                         'BsmtFullBath','BsmtHalfBath','FullBath',
                         'HalfBath','1stFlrSF','2ndFlrSF',
                         'OverallQual','OverallCond'])

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=42)

model = LinearRegression()
model.fit(X_train,y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
rmse = sqrt(mse)
r2 = r2_score(y_test,y_pred)

beta_0 = model.intercept_
beta_i = model.coef_

print('mean squared error: ', mse)
print('root mean squared error: ', rmse)
print('R squared: ', r2)
print('---------------------')
print('Intercept: ', beta_0)
print('Coefficients: ', beta_i)
# Out:
# mean squared error:  0.02272951955471559
# root mean squared error:  0.1507631239883135
# R squared:  0.878200037338549
# ---------------------
# Intercept:  13.228056522477532
# Coefficients:  [-5.98173630e-04  1.57014662e-06  3.42634477e-03  9.85859491e-04
#   3.74003619e-05  1.35222297e-05  1.48721066e-05  6.57892673e-05
#   9.67544849e-05  1.32847007e-04 -9.94861335e-03 -6.91207102e-02
#   1.93272182e-02  5.37997784e-02  8.01156310e-02  2.43980400e-05
#   1.18696568e-04 -6.04442249e-05  2.46231615e-04  2.57570418e-04
#   3.29148107e-04 -4.25412127e-04 -5.48663030e-06  8.80637797e-04
#  -5.46356291e-03  5.56797943e-02  3.60924867e-05  2.17230463e+01]

# %%
## going to readd some features
df_hope = df.select_dtypes(include=['float','int']).dropna(axis=1)

y = df_hope['ln_price']
X = df_hope.drop(columns=['SalePrice','ln_price','Id',
                         'BsmtFullBath','BsmtHalfBath','FullBath',
                         'HalfBath','1stFlrSF','2ndFlrSF',
                         'OverallQual','OverallCond',
                         'Ones_Foundation','Ones_HeatingQC','Ones_Heating'])

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=42)

model = LinearRegression()
model.fit(X_train,y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
rmse = sqrt(mse)
r2 = r2_score(y_test,y_pred)

beta_0 = model.intercept_
beta_i = model.coef_

print('mean squared error: ', mse)
print('root mean squared error: ', rmse)
print('R squared: ', r2)
print('---------------------')
print('Intercept: ', beta_0)
print('Coefficients: ', beta_i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-a7332a206b49> in <module>
#       7                          'HalfBath','1stFlrSF','2ndFlrSF',
#       8                          'OverallQual','OverallCond',
# ----> 9                          'Ones_Foundation','Ones_HeatingQC','Ones_Heating'])
#      10
#      11 X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=42)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['Ones_Foundation' 'Ones_HeatingQC' 'Ones_Heating'] not found in axis"

# %% [markdown]
# # Stretch Goals
#
# - Write a blog post explaining one of today's topics.
# - Find a new regression dataset from the UCI machine learning repository and use it to test out your new modeling skillz.
#  [ - UCI Machine Learning Repository - Regression Datasets](https://)
# - Make a list for yourself of common feature engineering techniques. Browse Kaggle kernels to learn more methods.
# - Start studying for tomorrow's topic: Gradient Descent
# - Try and make the ultimate model with this dataset. clean as many features as possible, engineer the most sensible features as possible and see how accurate of a prediction you can make.
# - Learn about the "Dummy Variable Trap" and how it applies to linear regression modeling.
# - Learning about using linear regression to model time series data
